# %% [markdown]
# # Intrusion detection system (IDS)

# %% [markdown]
# ## Author: Abolfazl Vakily

# %% [markdown]
# ### University Of Imamreza

# %% [markdown]
# # concepts

# %% [markdown]
# ![alt text](./assets/pic/2.png "What is ml")

# %% [markdown]
# # Cloud

# %% [markdown]
# ![alt text](./assets/pic/3.png "What is ml")

# %% [markdown]
# # Device

# %% [markdown]
# ![alt text](./assets/pic/4.png "What is ml")

# %% [markdown]
# # Example

# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics
from assets.preparation import (data,
                                columns_names,
                                X_test,
                                y_test,
                                test,
                                )

# %%
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
data['class'].value_counts().plot.pie(figsize=(8, 8));

# %%
columns_names
# Out:
#                          column
# 0                      duration
# 1                 protocol_type
# 2                       service
# 3                          flag
# 4                     src_bytes
# 5                     dst_bytes
# 6                          land
# 7                wrong_fragment
# 8                        urgent
# 9                           hot
# 10            num_failed_logins
# 11                    logged_in
# 12              num_compromised
# 13                   root_shell
# 14                 su_attempted
# 15                     num_root
# 16           num_file_creations
# 17                   num_shells
# 18             num_access_files
# 19            num_outbound_cmds
# 20                is_host_login
# 21               is_guest_login
# 22                        count
# 23                    srv_count
# 24                  serror_rate
# 25              srv_serror_rate
# 26                  rerror_rate
# 27              srv_rerror_rate
# ...

# %% [markdown]
# ## Features Document

# %%
# !ls ./assets/doc
# Out:
# doc.odt

# %% [markdown]
# # Import model

# %%
with open('assets/model/model.pkl', 'rb') as file:
    model = pickle.load(file)

# %% [markdown]
# # Validation

# %%
print(metrics.classification_report(y_test, model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#      anomaly       0.99      1.00      0.99      3498
#       normal       1.00      0.99      1.00      4060
#
#     accuracy                           0.99      7558
#    macro avg       0.99      1.00      0.99      7558
# weighted avg       0.99      0.99      0.99      7558

# %%
test['class_pred'] = model.predict(test)

# %%
test.head()
# Out:
#    duration  src_bytes  dst_bytes      land  wrong_fragment    urgent  \
# 0 -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
# 1 -0.155534  -0.021988  -0.096896 -0.017624       -0.059104 -0.019459
# 2 -0.154113   0.005473  -0.096896 -0.017624       -0.059104 -0.019459
# 3 -0.155534  -0.021946  -0.096896 -0.017624       -0.059104 -0.019459
# 4 -0.154823  -0.021988  -0.096189 -0.017624       -0.059104 -0.019459
#
#         hot  num_failed_logins  logged_in  num_compromised  ...  \
# 0 -0.113521          -0.143999  -0.890373        -0.016494  ...
# 1 -0.113521          -0.143999  -0.890373        -0.016494  ...
# 2 -0.113521          -0.143999  -0.890373        -0.016494  ...
# 3 -0.113521          -0.143999  -0.890373        -0.016494  ...
# 4 -0.113521          -0.143999  -0.890373        -0.016494  ...
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                    -0.431856                    -0.229980
# ...
